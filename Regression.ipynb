# %%
filePath <- "/Users/yunbo/Documents/GitHub/Statistical-Learning-in-Practice/"
fileName <- "BostonHousing.csv"
housing <- read.csv(paste0(filePath, fileName))
head(housing)
# Out:
#   crim    zn indus chas nox   rm    age  dis    rad tax ptratio b      lstat
# 1 0.00632 18 2.31  0    0.538 6.575 65.2 4.0900 1   296 15.3    396.90 4.98
# 2 0.02731  0 7.07  0    0.469 6.421 78.9 4.9671 2   242 17.8    396.90 9.14
# 3 0.02729  0 7.07  0    0.469 7.185 61.1 4.9671 2   242 17.8    392.83 4.03
# 4 0.03237  0 2.18  0    0.458 6.998 45.8 6.0622 3   222 18.7    394.63 2.94
# 5 0.06905  0 2.18  0    0.458 7.147 54.2 6.0622 3   222 18.7    396.90 5.33
# 6 0.02985  0 2.18  0    0.458 6.430 58.7 6.0622 3   222 18.7    394.12 5.21
#   medv
# 1 24.0
# 2 21.6
# 3 34.7
# 4 33.4
# 5 36.2
# 6 28.7

# %%
summary(housing)
# Out:
#       crim                zn             indus            chas
#  Min.   : 0.00632   Min.   :  0.00   Min.   : 0.46   Min.   :0.00000
#  1st Qu.: 0.08205   1st Qu.:  0.00   1st Qu.: 5.19   1st Qu.:0.00000
#  Median : 0.25651   Median :  0.00   Median : 9.69   Median :0.00000
#  Mean   : 3.61352   Mean   : 11.36   Mean   :11.14   Mean   :0.06917
#  3rd Qu.: 3.67708   3rd Qu.: 12.50   3rd Qu.:18.10   3rd Qu.:0.00000
#  Max.   :88.97620   Max.   :100.00   Max.   :27.74   Max.   :1.00000
#       nox               rm             age              dis
#  Min.   :0.3850   Min.   :3.561   Min.   :  2.90   Min.   : 1.130
#  1st Qu.:0.4490   1st Qu.:5.886   1st Qu.: 45.02   1st Qu.: 2.100
#  Median :0.5380   Median :6.208   Median : 77.50   Median : 3.207
#  Mean   :0.5547   Mean   :6.285   Mean   : 68.57   Mean   : 3.795
#  3rd Qu.:0.6240   3rd Qu.:6.623   3rd Qu.: 94.08   3rd Qu.: 5.188
#  Max.   :0.8710   Max.   :8.780   Max.   :100.00   Max.   :12.127
# ...

# %%
cor(housing)
# Out:
#         crim        zn          indus       chas         nox
# crim     1.00000000 -0.20046922  0.40658341 -0.055891582  0.42097171
# zn      -0.20046922  1.00000000 -0.53382819 -0.042696719 -0.51660371
# indus    0.40658341 -0.53382819  1.00000000  0.062938027  0.76365145
# chas    -0.05589158 -0.04269672  0.06293803  1.000000000  0.09120281
# nox      0.42097171 -0.51660371  0.76365145  0.091202807  1.00000000
# rm      -0.21924670  0.31199059 -0.39167585  0.091251225 -0.30218819
# age      0.35273425 -0.56953734  0.64477851  0.086517774  0.73147010
# dis     -0.37967009  0.66440822 -0.70802699 -0.099175780 -0.76923011
# rad      0.62550515 -0.31194783  0.59512927 -0.007368241  0.61144056
# tax      0.58276431 -0.31456332  0.72076018 -0.035586518  0.66802320
# ptratio  0.28994558 -0.39167855  0.38324756 -0.121515174  0.18893268
# b       -0.38506394  0.17552032 -0.35697654  0.048788485 -0.38005064
# lstat    0.45562148 -0.41299457  0.60379972 -0.053929298  0.59087892
# ...

# %%
bright_color <- "orange"  # You can change this to any bright color you prefer
pairs(housing, col = bright_color)
# Out:
# plot without title

# %%
housing.lm1 <- lm(medv ~ crim + nox + rm + age + ptratio, data = housing)
summary(housing.lm1)
# Out:
# Call:
# lm(formula = medv ~ crim + nox + rm + age + ptratio, data = housing)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -14.111  -3.157  -0.535   1.884  39.799
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   5.82952    4.44993   1.310  0.19079
# crim         -0.13806    0.03364  -4.104 4.74e-05 ***
# nox         -10.97965    3.40150  -3.228  0.00133 **
# rm            6.91636    0.40175  17.215  < 2e-16 ***
# age          -0.01270    0.01352  -0.940  0.34775
# ptratio      -1.04592    0.13145  -7.957 1.19e-14 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 5.725 on 500 degrees of freedom
# Multiple R-squared:  0.6163,	Adjusted R-squared:  0.6125
# F-statistic: 160.6 on 5 and 500 DF,  p-value: < 2.2e-16
